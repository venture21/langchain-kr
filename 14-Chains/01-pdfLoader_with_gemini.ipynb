# %%
from google import genai
from google.genai import types
import pathlib
import httpx

client = genai.Client()

# Retrieve and encode the PDF byte
file_path = pathlib.Path("data/deoksugung_pamphlet.pdf")


# Upload the PDF using the File API
sample_file = client.files.upload(
    file=file_path,
)

prompt = """pdf파일에서 텍스트 내용을 추출해줘. pdf는 페이지가 가로로 4페이지가 나란히 배치되어 있어.
            왼쪽페이지부터 차례로 읽어주고 불필요한 정보는 삭제해줘.
        """

response = client.models.generate_content(
    model="gemini-2.5-flash", contents=[sample_file, prompt]
)
print(response.text)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# 다음은 PDF 페이지에서 추출된 텍스트입니다.
#
# ---
#
# **관람 정보**
#
# 궁능유적본부 덕수궁관리소 SNS
#
# **관람시간**
# *   **덕수궁:** 09:00-21:00 (입장마감 20:00)
# *   **석조전 내부:** 예약관람 09:00-17:30 (입장마감 17:00)
# *   **돈덕전:** 09:30-17:30 (입장마감 17:00)
# *   **고종의 길:** 09:00-17:30 (입장마감 17:20)
# *   **정기휴일:** 매주 월요일
#
# **관람요금**
# *   **개인 (만 25세-만 64세):** 1,000원
# *   **단체(10인 이상):** 800원
# *   만 24세 이하 및 만 65세 이상 내국인 무료
# *   지역(중구) 주민 50% 할인
# *   중명전은 무료
#
# **관람해설**
# *   자세한 언어권별 무료 안내해설 시간은 궁능유적본부 누리집(royal.khs.go.kr) 관람안내를 참고하시기 바랍니다.
# *   상황에 따라 관람과 해설 안내 시간이 변경 또는 취소될 수 있습니다.
#
# **덕수궁**
# *   덕수궁 전각해설은 정문에서 20m 직진한 곳에 있는 종합안내판 앞에서 시작
# *   개인관람객(10인 미만)은 별도 예약없이 해설 참여 가능
# *   단체관람객(10인 이상)의 해설 참여는 사전예약 필수
# *   외국어 전각해설은 외국인만 참여 가능 (단, 외국인을 동반한 내국인에 한하여 참여 가능)
# *   공휴일은 외국어 해설 없음
#
# **석조전 대한제국역사관**
# *   궁능유적본부 누리집에서 예약 후 해설사와 동반하여 제한 관람 (선착순, 1인당 최대 5매까지 예약 가능)
# *   영어 관람해설은 외국인에 한하여 현장예약 문의 (단, 외국인을 동반한 내국인에 한하여 참여 가능)
#
# **오시는 길**
# *   시청역 1호선 2번 출구, 2호선 12번 출구
# *   덕수궁에는 주차장이 없습니다.
# *   04519 서울특별시 중구 세종대로 99 / 02-771-9951
#
# **덕수궁/석조전/돈 덕전/중명전 대한제국의 황궁**
#
# 덕수궁은 조선 제14대 왕 선조가 임진왜란 때 피난을 갔다가 돌아온 후 월산대군의 후손들이 살던 집을 임시 거처[정릉동 행궁]로 삼으면서 처음 궁궐로 사용되었다. 이후 광해군이 창덕궁으로 옮겨 가면서 정릉동 행궁에 '경운궁慶運宮'이라는 이름을 붙였다. 경운궁에 다시 왕이 머문 것은 조선 제26대 왕 고종이 러시아공사관에 잠시 머물다가 경운궁으로 옮겨 오면서부터이다.
#
# 고종은 경운궁으로 돌아와 국호를 조선에서 대한제국으로 바꾸고, 환구단을 지어 하늘에 제사를 지낸 뒤 황제의 자리에 올랐다. 고종은 황제국의 위상에 걸맞게 여러 전각을 세우고 영역을 확장하였다. 당시 궁궐 영역은 현재의 약 세 배 규모였다. 1907년 일본의 강압에 의하여 고종이 황제의 자리에서 물러나면서부터 경운궁은 덕수궁德壽宮으로 불리었다. 고종은 1919년 승하할 때까지 덕수궁에서 지냈으며, 고종 승하 이후 덕수궁 권역이 빠르게 해체 및 축소되었다.
#
# **[덕수궁 안내도 범례]**
# 1 덕수궁 소개
# 2 대한문
# 3 중화문
# 4 중화전
# 5 준명당
# 6 즉조당
# 7 석어당
# 8 덕홍전
# 9 함녕전
# 10 정관헌
# 11 석조전 대한제국역사관
# 12 국립현대미술관 덕수궁관
# 13 광명문
# 14 돈덕전
# 15 고종의 길
# 16 중명전
#
# **[기타 시설 및 정보]**
# 1910년경 덕수궁 영역
# 해설 시작 장소
# 매표소
# 화장실
# 지하철
# ◆ 기념품점
# • 휠체어 대여소
# 수유실
# 카페
# 구급약품
# • 물품보관함
# 자동 심장 충격기
#
# ---
#
# **대한제국 황궁 덕수궁**
#
# **[연혁]**
# *   1392 조선 건국
# *   1592 임진왜란 발발
# *   1593 월산대군 후손의 저택을 임시 궁궐로 삼고, '정릉동 행궁'이라 부름
# *   1608 선조, 석어당(추정)에서 승하 / 광해군, 즉조당(추정)에서 즉위
# *   1611 광해군, 창덕궁으로 옮김. 정릉동 행궁을 '경운궁'이라 칭함 / 광해군, 경운궁으로 다시 옮김
# *   1615 광해군, 창덕궁으로 다시 옮김
# *   1618 인목대비를 폐위하여 석어당(추정)에 유폐
# *   1623 인조, 즉조당(추정)에서 즉위. 창덕궁으로 옮김
# *   1876 강화도 조약 체결. 문호 개방 시작
# *   1896 고종, 러시아 공사관으로 피신
# *   1897 고종, 경운궁으로 옮김. 대한제국 선포
# *   1902~3 돈덕전 건립
# *   1904 대화재로 중화전, 석어당, 함녕전 등 전각 소실
# *   1905 중명전에서 을사늑약 강제 체결
# *   1906 대안문을 수리하고 '대한문'으로 개칭
# *   1907 순종, 즉위 후 창덕궁으로 옮김 / 경운궁을 '덕수궁'으로 부르기 시작
# *   1910 석조전 완공. 국권 피탈
# *   1919 함녕전에서 고종 승하
# *   1920년대 돈덕전 훼철
# *   1938 석조전 서관 완공. '이왕가미술관'으로 개관
# *   1945 광복
# *   1946~7 석조전에서 미소공동위원회 열림
# *   2010 중명전 전시관 개관
# *   2014 석조전 대한제국역사관 개관
# *   2023 돈덕전 재건 및 개관
#
# **중화전 영역**
# 고종은 1897년 대한제국을 선포한 후 황제국의 위상에 맞게 덕수궁을 정비하였다. 정전인 중화전 기단의 답도*에는 용 문양을 새기고, 창호를 황금색으로 칠하여 황제국의 위용을 갖추었다. 중화전은 1902년 지었을 때 중층이었지만, 1904년 화재를 겪고 1905년 다시 지으면서 단층으로 축소되었다. 중화전 남쪽 중화문을 둘러싸고 사방에 행각을 둘렀는데, 일제 강점기 이후 주변 행각과 전각이 헐리고 정원이 생기면서 현재와 같은 모습이 되었다.
# 즉조당과 석어당은 선조가 임시로 거처했을 때부터 사용한 유서 깊은 건물이다. 즉조당은 대한제국 초기에 정전으로 사용되었다가 중화전이 완성된 이후 편전으로 활용되었다. 석어당은 덕수궁에 남아 있는 유일한 중층 목조 전각이다. 1904년에 불타 없어졌던 것을 1905년 다시 지었다.
# *답도(踏道): 궁궐에서 임금이 가마를 타고 지나가는 계단
# [사진 설명] 1904년 화재 이전의 덕수궁 (국립고궁박물관), 화재 이후의 덕수궁 (국립고궁박물관), 준명당 및 즉조당, 석어당, 덕수궁 중화전 및 중화문 (보물)
#
# **함녕전 영역**
# 함녕전은 고종의 침전으로 사용되었고, 고종이 승하한 장소이기도 하다.
# 다른 궁궐과 달리 덕수궁에는 황후의 침전이 따로 없는데, 그 이유는 명성황후가 1895년 을미사변으로 경복궁에서 시해된 후 고종이 다시 황후를 맞이하지 않았기 때문이다. 황후의 침전을 대신하여 명성황후의 신주*를 모신 경효전을 세웠다. 경효전은 1904년 화재로 불타 없어지고, 그 자리에 덕홍전이 전해온다. 덕홍전은 외국 사신을 접견할 목적으로 사용되었으며 외관은 전통식이지만 내부는 서양식으로 꾸몄다.
# 정관헌은 고종과 순종의 어진이 제작되고 어진, 어보, 옥책 등을 봉안한 건물이다. 서양식 건축양식에 박쥐, 사슴 등 전통 문양으로 장식하였다.
# *신주(神主): 죽은 사람의 혼령이 깃들어 머문다고 인식되는 나무패
# [사진 설명] 덕수궁 함녕전 (보물), 덕홍전, 덕수궁과 조선 - 대한제국의 역사 정관헌
#
# **석조전**
# 석조전은 1897년 대한제국 선포 후 건립을 계획하여 1900년 착공하였고, 1910년에 준공하였다. 엄격한 비례와 좌우대칭이 돋보이는 신고전주의 양식으로 내부에 접견실, 대식당, 침실과 서재 등을 갖춘 근대 건축물이다. 황실의 공적 공간인 1층은 중앙홀, 접견실 등을, 황실의 사적 공간인 2층은 황제 침실, 황후 거실 등을 재현하였다. 석조전은 일제강점기 이후 다양한 용도로 사용하면서 훼손되었지만 2014년에 1910년 준공 당시의 모습으로 복원하여 석조전 대한제국역사관으로 개관하였다.
# [사진 설명] 석조전 1층 내부, 2층 내부
#
# **돈덕전**
# 돈덕전은 대한제국의 서양식 외교 건물로, 1902~3년에 고종 즉위 40주년 기념 예식에 맞추어 대규모 국제행사장으로 지어졌다. 이 건물은 국제교류를 실현하고 열강과 대등한 근대국가의 모습과 주권 수호의 의지를 세계에 보여주기 위하여 건립되었다. 프랑스 파리에서 유행하였던 화려한 건축양식을 사용하였고, 외교 사절의 접견실이자 연회장, 국빈급 외국인의 숙소 등으로 사용되었다. 1907년에는 순종의 황제 즉위식이 열리기도 하였다. 돈덕전은 1920년대 일제에 의해 훼철되었으나, 복원정비사업을 거쳐 2023년에 개관하였다.
# [사진 설명] 돈덕전 중앙홀, 황제 침실, 복도, 상설전시실, 아카이브실
#
# **중명전**
# 중명전은 덕수궁을 대한제국 황궁으로 정비하는 과정에서 황실 서적과 보물을 보관할 황제의 서재로 지어졌다. 당시 건물의 이름은 수옥헌漱玉軒이었다. 1904년 덕수궁 화재로 고종이 중명전으로 이어移御하면서 편전으로 사용되었다. 그러나 이듬해인 1905년 일본의 강압으로 을사늑약이 체결되는 비운의 장소가 되었다.
# [사진 설명] 중명전 전경, 내부 전시관
