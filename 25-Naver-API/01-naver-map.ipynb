# %% [markdown]
# #### 네이버 개발자 센터에서 회원가입
# https://developers.naver.com/main/

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import requests
import json
import os

# 네이버 개발자 센터에서 발급받은 Client ID와 Secret
client_id = os.getenv("NAVER_CLIENT_ID")  # "YOUR_CLIENT_ID"
client_secret = os.getenv("NAVER_CLIENT_SECRET")  #

# 검색할 키워드
query = "상일동역 중화요리"

# API 요청 URL
url = f"https://openapi.naver.com/v1/search/local.json?query={query}&display=5"

# HTTP 헤더에 인증 정보 추가
headers = {"X-Naver-Client-Id": client_id, "X-Naver-Client-Secret": client_secret}

# API 요청 보내기
response = requests.get(url, headers=headers)
data = response.json()

# 결과 출력
print(json.dumps(data, indent=2, ensure_ascii=False))
# Out:
# {
#   "lastBuildDate": "Thu, 11 Sep 2025 11:17:35 +0900",
#   "total": 5,
#   "start": 1,
#   "display": 5,
#   "items": [
#     {
#       "title": "정가짬뽕",
#       "link": "",
#       "category": "중식>중식당",
#       "description": "",
#       "telephone": "",
#       "address": "서울특별시 강동구 고덕동 693 그라시움 아파트종합상가 2층 243호",
#       "roadAddress": "서울특별시 강동구 고덕로 353 그라시움 아파트종합상가 2층 243호",
#       "mapx": "1271645103",
#       "mapy": "375571351"
#     },
#     {
#       "title": "명성반점",
#       "link": "",
#       "category": "중식>중식당",
#       "description": "",
#       "telephone": "",
#       "address": "서울특별시 강동구 고덕동 193-1 1층 101 호",
#       "roadAddress": "서울특별시 강동구 상일로15길 30 1층 101 호",
#       "mapx": "1271695390",
#       "mapy": "375582173"
#     },
#     {
#       "title": "린칭",
#       "link": "",
#       "category": "중식>중식당",
#       "description": "",
#       "telephone": "",
#       "address": "서울특별시 강동구 고덕동 694 고덕그라시움아파트 4상가 2층 210호",
#       "roadAddress": "서울특별시 강동구 고덕로 385 고덕그라시움아파트 4상가 2층 210호",
#       "mapx": "1271684125",
#       "mapy": "375573672"
#     },
#     {
#       "title": "라홍방마라탕 상일역점",
#       "link": "http://www.lahongbang.com/",
#       "category": "음식점>마라탕",
#       "description": "",
#       "telephone": "",
#       "address": "서울특별시 강동구 고덕동 210-1 고덕센트럴푸르지오 메가스퀘어동 지하1층 B125호",
#       "roadAddress": "서울특별시 강동구 고덕로 399 고덕센트럴푸르지오 메가스퀘어동 지하1층 B125호",
#       "mapx": "1271696946",
#       "mapy": "375579222"
#     },
#     {
#       "title": "홍콩반점0410 <b>상일동역</b>점",
#       "link": "https://start.theborn.co.kr/prebrand_detail.php?bc=26",
#       "category": "음식점>중식당",
#       "description": "",
#       "telephone": "",
#       "address": "서울특별시 강동구 고덕동 195",
#       "roadAddress": "서울특별시 강동구 상일로17길 29-5",
#       "mapx": "1271692678",
#       "mapy": "375585973"
#     }
#   ]
# }
