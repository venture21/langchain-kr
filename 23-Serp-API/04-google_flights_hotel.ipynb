# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# import os
# os.getenv("SERPAPI_API_KEY")

# %% [markdown]
# ### google_flights

# %%
import os
import json
from serpapi import GoogleSearch

# SerpApi 클라이언트를 초기화하기 위한 파라미터를 설정합니다.
# 검색 엔진, 출발 공항 코드, 도착 공항 코드, 날짜 등을 지정합니다.
params = {
    "engine": "google_flights",
    "departure_id": "ICN",  # 인천 (Incheon)
    "arrival_id": "JFK",  # 뉴욕 (New York John F. Kennedy)
    "outbound_date": "2025-09-13",
    "return_date": "2025-09-15",
    "currency": "KRW",
    "hl": "ko",
    "api_key": os.getenv("SERPAPI_API_KEY"),
}

# 파라미터를 사용하여 GoogleSearch 객체를 생성합니다.
search = GoogleSearch(params)

try:
    # 검색을 실행하고 결과를 딕셔너리 형태로 가져옵니다.
    results = search.get_dict()

    # 결과가 있는지 확인합니다.
    if "best_flights" in results:
        print("✅ 검색 성공! 가장 저렴한 항공편 정보를 출력합니다.")
        # 가독성을 위해 JSON 형식으로 예쁘게 출력합니다.
        print(json.dumps(results["best_flights"], indent=2, ensure_ascii=False))

        # 다른 항공편 정보도 출력할 수 있습니다.
        if "other_flights" in results and results["other_flights"]:
            print("\n✈️ 다른 항공편 정보 (첫 5개):")
            other_flights_sample = results["other_flights"][:5]
            print(json.dumps(other_flights_sample, indent=2, ensure_ascii=False))

    elif "error" in results:
        print(f"❌ 검색 중 오류가 발생했습니다: {results['error']}")
    else:
        print("⚠️ 항공편 정보를 찾을 수 없습니다. 다른 날짜나 공항으로 시도해보세요.")
        print("\n전체 응답:")
        print(json.dumps(results, indent=2, ensure_ascii=False))

except Exception as e:
    print(f"스크립트 실행 중 예외가 발생했습니다: {e}")
# Out:
# ✅ 검색 성공! 가장 저렴한 항공편 정보를 출력합니다.
# [
#   {
#     "flights": [
#       {
#         "departure_airport": {
#           "name": "인천국제공항",
#           "id": "ICN",
#           "time": "2025-09-13 17:25"
#         },
#         "arrival_airport": {
#           "name": "달라스 / 포트 워스 국제공항",
#           "id": "DFW",
#           "time": "2025-09-13 16:20"
#         },
#         "duration": 775,
#         "airplane": "Boeing 777",
#         "airline": "아메리칸항공",
#         "airline_logo": "https://www.gstatic.com/flights/airline_logos/70px/AA.png",
#         "travel_class": "Economy",
#         "flight_number": "AA 280",
#         "legroom": "79cm",
#         "extensions": [
#           "Average legroom (79cm)",
#           "Wi-Fi for a fee",
#           "In-seat power & USB outlets",
#           "On-demand video",
#           "Carbon emissions estimate: 648 kg"
#         ],
#         "overnight": true,
#         "often_delayed_by_over_30_min": true
#       },
#       {
#         "departure_airport": {
#           "name": "달라스 / 포트 워스 국제공항",
#           "id": "DFW",
#           "time": "2025-09-14 07:14"
#         },
#         "arrival_airport": {
#           "name": "존 F. 케네디 국제공항",
#           "id": "JFK",
#           "time": "2025-09-14 11:59"
#         },
#         "duration": 225,
#         "airplane": "Boeing 737",
#         "airline": "아메리칸항공",
#         "airline_logo": "https://www.gstatic.com/flights/airline_logos/70px/AA.png",
#         "travel_class": "Economy",
#         "flight_number": "AA 1628",
#         "legroom": "76cm",
#         "extensions": [
#           "Average legroom (76cm)",
#           "Wi-Fi for a fee",
#           "In-seat power & USB outlets",
#           "Stream media to your device",
#           "Carbon emissions estimate: 197 kg"
#         ]
#       }
#     ],
#     "layovers": [
#       {
#         "duration": 894,
#         "name": "달라스 / 포트 워스 국제공항",
#         "id": "DFW",
#         "overnight": true
#       }
#     ],
#     "total_duration": 1894,
#     "carbon_emissions": {
#       "this_flight": 846000,
#       "typical_for_this_route": 745000,
#       "difference_percent": 14
#     },
#     "price": 748800,
#     "type": "Round trip",
#     "airline_logo": "https://www.gstatic.com/flights/airline_logos/70px/AA.png",
#     "departure_token": ""
#   },
#   {
#     "flights": [
#       {
#         "departure_airport": {
#           "name": "인천국제공항",
#           "id": "ICN",
#           "time": "2025-09-13 21:05"
#         },
#         "arrival_airport": {
#           "name": "존 F. 케네디 국제공항",
#           "id": "JFK",
#           "time": "2025-09-13 23:00"
#         },
#         "duration": 895,
#         "airplane": "Airbus A350",
#         "airline": "아시아나항공",
#         "airline_logo": "https://www.gstatic.com/flights/airline_logos/70px/OZ.png",
#         "travel_class": "Economy",
#         "flight_number": "OZ 224",
#         "legroom": "81cm",
#         "extensions": [
#           "Above average legroom (81cm)",
#           "Wi-Fi for a fee",
#           "In-seat power & USB outlets",
#           "On-demand video",
#           "Carbon emissions estimate: 724 kg"
#         ],
#         "overnight": true
#       }
#     ],
#     "total_duration": 895,
#     "carbon_emissions": {
#       "this_flight": 724000,
#       "typical_for_this_route": 745000,
#       "difference_percent": -3
#     },
#     "price": 1001500,
#     "type": "Round trip",
#     "airline_logo": "https://www.gstatic.com/flights/airline_logos/70px/OZ.png",
#     "departure_token": "WyJDalJJYUdvMFlVTm5TMVpwVG10QlFYVlZZa0ZDUnkwdExTMHRMUzB0ZG5SaVluVTFNVUZCUVVGQlIycERTMDFGUldsMlVGTkJFZ1ZQV2pJeU5Cb0xDSnlRUFJBQUdnTkxVbGM0SEhEOHN3UT0iLFtbIklDTiIsIjIwMjUtMDktMTMiLCJKRksiLG51bGwsIk9aIiwiMjI0Il1dXQ=="
#   },
#   {
#     "flights": [
#       {
#         "departure_airport": {
#           "name": "인천국제공항",
#           "id": "ICN",
#           "time": "2025-09-13 19:40"
#         },
#         "arrival_airport": {
#           "name": "솔트레이크시티 국제공항",
#           "id": "SLC",
#           "time": "2025-09-13 16:05"
#         },
#         "duration": 685,
#         "airplane": "Airbus A350",
#         "airline": "델타항공",
#         "airline_logo": "https://www.gstatic.com/flights/airline_logos/70px/DL.png",
#         "travel_class": "Economy",
#         "flight_number": "DL 172",
#         "legroom": "79cm",
#         "extensions": [
#           "Average legroom (79cm)",
#           "Free Wi-Fi",
#           "In-seat power & USB outlets",
#           "On-demand video",
#           "Carbon emissions estimate: 578 kg"
#         ],
#         "overnight": true
#       },
#       {
#         "departure_airport": {
#           "name": "솔트레이크시티 국제공항",
#           "id": "SLC",
#           "time": "2025-09-13 17:45"
#         },
#         "arrival_airport": {
#           "name": "존 F. 케네디 국제공항",
#           "id": "JFK",
#           "time": "2025-09-14 00:22"
#         },
#         "duration": 277,
#         "airplane": "Airbus A321neo",
#         "airline": "델타항공",
#         "airline_logo": "https://www.gstatic.com/flights/airline_logos/70px/DL.png",
#         "travel_class": "Economy",
#         "flight_number": "DL 697",
#         "legroom": "79cm",
#         "extensions": [
#           "Average legroom (79cm)",
#           "Free Wi-Fi",
#           "In-seat power & USB outlets",
#           "Live TV",
#           "Carbon emissions estimate: 211 kg"
#         ]
#       }
#     ],
#     "layovers": [
#       {
#         "duration": 100,
#         "name": "솔트레이크시티 국제공항",
#         "id": "SLC"
#       }
#     ],
#     "total_duration": 1062,
#     "carbon_emissions": {
#       "this_flight": 790000,
#       "typical_for_this_route": 745000,
#       "difference_percent": 6
#     },
#     "price": 1082900,
#     "type": "Round trip",
#     "airline_logo": "https://www.gstatic.com/flights/airline_logos/70px/DL.png",
#     "departure_token": ""
#   },
#   {
#     "flights": [
#       {
#         "departure_airport": {
#           "name": "인천국제공항",
#           "id": "ICN",
#           "time": "2025-09-13 09:00"
#         },
#         "arrival_airport": {
#           "name": "존 F. 케네디 국제공항",
#           "id": "JFK",
#           "time": "2025-09-13 10:15"
#         },
#         "duration": 855,
#         "airplane": "Airbus A350",
#         "airline": "아시아나항공",
#         "airline_logo": "https://www.gstatic.com/flights/airline_logos/70px/OZ.png",
#         "travel_class": "Economy",
#         "flight_number": "OZ 222",
#         "legroom": "81cm",
#         "extensions": [
#           "Above average legroom (81cm)",
#           "Wi-Fi for a fee",
#           "In-seat power & USB outlets",
#           "On-demand video",
#           "Carbon emissions estimate: 724 kg"
#         ],
#         "overnight": true
#       }
#     ],
#     "total_duration": 855,
#     "carbon_emissions": {
#       "this_flight": 724000,
#       "typical_for_this_route": 745000,
#       "difference_percent": -3
#     },
#     "price": 1551500,
#     "type": "Round trip",
#     "airline_logo": "https://www.gstatic.com/flights/airline_logos/70px/OZ.png",
#     "departure_token": "WyJDalJJYUdvMFlVTm5TMVpwVG10QlFYVlZZa0ZDUnkwdExTMHRMUzB0ZG5SaVluVTFNVUZCUVVGQlIycERTMDFGUldsMlVGTkJFZ1ZQV2pJeU1ob0xDSXpaWGhBQUdnTkxVbGM0SEhEWTZRWT0iLFtbIklDTiIsIjIwMjUtMDktMTMiLCJKRksiLG51bGwsIk9aIiwiMjIyIl1dXQ=="
#   }
# ]
#
# ✈️ 다른 항공편 정보 (첫 5개):
# [
#   {
#     "flights": [
#       {
#         "departure_airport": {
#           "name": "인천국제공항",
#           "id": "ICN",
#           "time": "2025-09-13 17:25"
#         },
#         "arrival_airport": {
#           "name": "달라스 / 포트 워스 국제공항",
#           "id": "DFW",
#           "time": "2025-09-13 16:20"
#         },
#         "duration": 775,
#         "airplane": "Boeing 777",
#         "airline": "아메리칸항공",
#         "airline_logo": "https://www.gstatic.com/flights/airline_logos/70px/AA.png",
#         "travel_class": "Economy",
#         "flight_number": "AA 280",
#         "legroom": "79cm",
#         "extensions": [
#           "Average legroom (79cm)",
#           "Wi-Fi for a fee",
#           "In-seat power & USB outlets",
#           "On-demand video",
#           "Carbon emissions estimate: 648 kg"
#         ],
#         "overnight": true,
#         "often_delayed_by_over_30_min": true
#       },
#       {
#         "departure_airport": {
#           "name": "달라스 / 포트 워스 국제공항",
#           "id": "DFW",
#           "time": "2025-09-13 18:50"
#         },
#         "arrival_airport": {
#           "name": "노퍽 국제공항",
#           "id": "ORF",
#           "time": "2025-09-13 22:53"
#         },
#         "duration": 183,
#         "airplane": "Boeing 737",
#         "airline": "아메리칸항공",
#         "airline_logo": "https://www.gstatic.com/flights/airline_logos/70px/AA.png",
#         "travel_class": "Economy",
#         "flight_number": "AA 2587",
#         "legroom": "76cm",
#         "extensions": [
#           "Average legroom (76cm)",
#           "Wi-Fi for a fee",
#           "In-seat power & USB outlets",
#           "Stream media to your device",
#           "Carbon emissions estimate: 163 kg"
#         ],
#         "often_delayed_by_over_30_min": true
#       },
#       {
#         "departure_airport": {
#           "name": "노퍽 국제공항",
#           "id": "ORF",
#           "time": "2025-09-14 06:00"
#         },
#         "arrival_airport": {
#           "name": "존 F. 케네디 국제공항",
#           "id": "JFK",
#           "time": "2025-09-14 07:24"
#         },
#         "duration": 84,
#         "airplane": "Embraer 175",
#         "airline": "아메리칸항공",
#         "airline_logo": "https://www.gstatic.com/flights/airline_logos/70px/AA.png",
#         "travel_class": "Economy",
#         "flight_number": "AA 4360",
#         "legroom": "76cm",
#         "extensions": [
#           "Average legroom (76cm)",
#           "Wi-Fi for a fee",
#           "In-seat power & USB outlets",
#           "Stream media to your device",
#           "Carbon emissions estimate: 84 kg"
#         ],
#         "plane_and_crew_by": "Republic Airways as American Eagle"
#       }
#     ],
#     "layovers": [
#       {
#         "duration": 150,
#         "name": "달라스 / 포트 워스 국제공항",
#         "id": "DFW"
#       },
#       {
#         "duration": 427,
#         "name": "노퍽 국제공항",
#         "id": "ORF",
#         "overnight": true
#       }
#     ],
#     "total_duration": 1619,
#     "carbon_emissions": {
#       "this_flight": 897000,
#       "typical_for_this_route": 745000,
#       "difference_percent": 20
#     },
#     "price": 748800,
#     "type": "Round trip",
#     "airline_logo": "https://www.gstatic.com/flights/airline_logos/70px/AA.png",
#     "departure_token": ""
#   },
#   {
#     "flights": [
#       {
#         "departure_airport": {
#           "name": "인천국제공항",
#           "id": "ICN",
#           "time": "2025-09-13 16:25"
#         },
#         "arrival_airport": {
#           "name": "하츠필드 잭슨 애틀랜타 국제공항",
#           "id": "ATL",
#           "time": "2025-09-13 17:15"
#         },
#         "duration": 830,
#         "airplane": "Airbus A350",
#         "airline": "델타항공",
#         "airline_logo": "https://www.gstatic.com/flights/airline_logos/70px/DL.png",
#         "travel_class": "Economy",
#         "flight_number": "DL 188",
#         "ticket_also_sold_by": [
#           "대한항공"
#         ],
#         "legroom": "79cm",
#         "extensions": [
#           "Average legroom (79cm)",
#           "Free Wi-Fi",
#           "In-seat power & USB outlets",
#           "On-demand video",
#           "Carbon emissions estimate: 684 kg"
#         ],
#         "overnight": true,
#         "often_delayed_by_over_30_min": true
#       },
#       {
#         "departure_airport": {
#           "name": "하츠필드 잭슨 애틀랜타 국제공항",
#           "id": "ATL",
#           "time": "2025-09-13 19:50"
#         },
#         "arrival_airport": {
#           "name": "존 F. 케네디 국제공항",
#           "id": "JFK",
#           "time": "2025-09-13 22:24"
#         },
#         "duration": 154,
#         "airplane": "Boeing 737",
#         "airline": "델타항공",
#         "airline_logo": "https://www.gstatic.com/flights/airline_logos/70px/DL.png",
#         "travel_class": "Economy",
#         "flight_number": "DL 2378",
#         "ticket_also_sold_by": [
#           "대한항공"
#         ],
#         "legroom": "79cm",
#         "extensions": [
#           "Average legroom (79cm)",
#           "Free Wi-Fi",
#           "In-seat power & USB outlets",
#           "Live TV",
#           "Carbon emissions estimate: 122 kg"
#         ],
#         "often_delayed_by_over_30_min": true
#       }
#     ],
#     "layovers": [
#       {
#         "duration": 155,
#         "name": "하츠필드 잭슨 애틀랜타 국제공항",
#         "id": "ATL"
#       }
#     ],
#     "total_duration": 1139,
#     "carbon_emissions": {
#       "this_flight": 807000,
#       "typical_for_this_route": 745000,
#       "difference_percent": 8
#     },
#     "price": 1101100,
#     "type": "Round trip",
#     "airline_logo": "https://www.gstatic.com/flights/airline_logos/70px/DL.png",
#     "departure_token": ""
#   },
#   {
#     "flights": [
#       {
#         "departure_airport": {
#           "name": "인천국제공항",
#           "id": "ICN",
#           "time": "2025-09-13 10:15"
#         },
#         "arrival_airport": {
#           "name": "디트로이트 메트로폴리탄 웨인 카운티 공항",
#           "id": "DTW",
#           "time": "2025-09-13 10:21"
#         },
#         "duration": 786,
#         "airplane": "Airbus A350",
#         "airline": "델타항공",
#         "airline_logo": "https://www.gstatic.com/flights/airline_logos/70px/DL.png",
#         "travel_class": "Economy",
#         "flight_number": "DL 158",
#         "legroom": "79cm",
#         "extensions": [
#           "Average legroom (79cm)",
#           "Free Wi-Fi",
#           "In-seat power & USB outlets",
#           "On-demand video",
#           "Carbon emissions estimate: 564 kg"
#         ],
#         "overnight": true
#       },
#       {
#         "departure_airport": {
#           "name": "디트로이트 메트로폴리탄 웨인 카운티 공항",
#           "id": "DTW",
#           "time": "2025-09-13 16:20"
#         },
#         "arrival_airport": {
#           "name": "존 F. 케네디 국제공항",
#           "id": "JFK",
#           "time": "2025-09-13 18:35"
#         },
#         "duration": 135,
#         "airplane": "Airbus A319",
#         "airline": "델타항공",
#         "airline_logo": "https://www.gstatic.com/flights/airline_logos/70px/DL.png",
#         "travel_class": "Economy",
#         "flight_number": "DL 2934",
#         "legroom": "79cm",
#         "extensions": [
#           "Average legroom (79cm)",
#           "Free Wi-Fi",
#           "In-seat power & USB outlets",
#           "Live TV",
#           "Carbon emissions estimate: 106 kg"
#         ]
#       }
#     ],
#     "layovers": [
#       {
#         "duration": 359,
#         "name": "디트로이트 메트로폴리탄 웨인 카운티 공항",
#         "id": "DTW"
#       }
#     ],
#     "total_duration": 1280,
#     "carbon_emissions": {
#       "this_flight": 671000,
#       "typical_for_this_route": 745000,
#       "difference_percent": -10
#     },
#     "price": 1176100,
#     "type": "Round trip",
#     "airline_logo": "https://www.gstatic.com/flights/airline_logos/70px/DL.png",
#     "departure_token": ""
#   },
#   {
#     "flights": [
#       {
#         "departure_airport": {
#           "name": "인천국제공항",
#           "id": "ICN",
#           "time": "2025-09-13 18:20"
#         },
#         "arrival_airport": {
#           "name": "시애틀 터코마 국제공항",
#           "id": "SEA",
#           "time": "2025-09-13 12:30"
#         },
#         "duration": 610,
#         "airplane": "Boeing 777",
#         "airline": "아시아나항공",
#         "airline_logo": "https://www.gstatic.com/flights/airline_logos/70px/OZ.png",
#         "travel_class": "Economy",
#         "flight_number": "OZ 272",
#         "legroom": "81cm",
#         "extensions": [
#           "Above average legroom (81cm)",
#           "In-seat power & USB outlets",
#           "On-demand video",
#           "Carbon emissions estimate: 582 kg"
#         ],
#         "overnight": true
#       },
#       {
#         "departure_airport": {
#           "name": "시애틀 터코마 국제공항",
#           "id": "SEA",
#           "time": "2025-09-13 14:35"
#         },
#         "arrival_airport": {
#           "name": "존 F. 케네디 국제공항",
#           "id": "JFK",
#           "time": "2025-09-13 22:59"
#         },
#         "duration": 324,
#         "airplane": "Boeing 737",
#         "airline": "알래스카항공",
#         "airline_logo": "https://www.gstatic.com/flights/airline_logos/70px/AS.png",
#         "travel_class": "Economy",
#         "flight_number": "AS 16",
#         "legroom": "79cm",
#         "extensions": [
#           "Average legroom (79cm)",
#           "Wi-Fi for a fee",
#           "In-seat power & USB outlets",
#           "Stream media to your device",
#           "Carbon emissions estimate: 281 kg"
#         ]
#       }
#     ],
#     "layovers": [
#       {
#         "duration": 125,
#         "name": "시애틀 터코마 국제공항",
#         "id": "SEA"
#       }
#     ],
#     "total_duration": 1059,
#     "carbon_emissions": {
#       "this_flight": 865000,
#       "typical_for_this_route": 745000,
#       "difference_percent": 16
#     },
#     "price": 1559300,
#     "type": "Round trip",
#     "airline_logo": "https://www.gstatic.com/flights/airline_logos/70px/multi.png",
#     "departure_token": ""
#   },
#   {
#     "flights": [
#       {
#         "departure_airport": {
#           "name": "인천국제공항",
#           "id": "ICN",
#           "time": "2025-09-13 09:30"
#         },
#         "arrival_airport": {
#           "name": "보스턴 로건 국제공항",
#           "id": "BOS",
#           "time": "2025-09-13 10:10"
#         },
#         "duration": 820,
#         "airplane": "Boeing 777",
#         "airline": "대한항공",
#         "airline_logo": "https://www.gstatic.com/flights/airline_logos/70px/KE.png",
#         "travel_class": "Economy",
#         "flight_number": "KE 91",
#         "ticket_also_sold_by": [
#           "델타항공"
#         ],
#         "legroom": "84cm",
#         "extensions": [
#           "Above average legroom (84cm)",
#           "In-seat power & USB outlets",
#           "On-demand video",
#           "Carbon emissions estimate: 842 kg"
#         ],
#         "overnight": true
#       },
#       {
#         "departure_airport": {
#           "name": "보스턴 로건 국제공항",
#           "id": "BOS",
#           "time": "2025-09-13 13:25"
#         },
#         "arrival_airport": {
#           "name": "존 F. 케네디 국제공항",
#           "id": "JFK",
#           "time": "2025-09-13 14:58"
#         },
#         "duration": 93,
#         "airplane": "Embraer 175",
#         "airline": "델타항공",
#         "airline_logo": "https://www.gstatic.com/flights/airline_logos/70px/DL.png",
#         "travel_class": "Economy",
#         "flight_number": "DL 5808",
#         "legroom": "79cm",
#         "extensions": [
#           "Average legroom (79cm)",
#           "Wi-Fi for a fee",
#           "Carbon emissions estimate: 82 kg"
#         ],
#         "plane_and_crew_by": "Republic Airways Delta Connection"
#       }
#     ],
#     "layovers": [
#       {
#         "duration": 195,
#         "name": "보스턴 로건 국제공항",
#         "id": "BOS"
#       }
#     ],
#     "total_duration": 1108,
#     "carbon_emissions": {
#       "this_flight": 926000,
#       "typical_for_this_route": 745000,
#       "difference_percent": 24
#     },
#     "price": 1576100,
#     "type": "Round trip",
#     "airline_logo": "https://www.gstatic.com/flights/airline_logos/70px/multi.png",
#     "departure_token": ""
#   }
# ]

# %% [markdown]
# ## google_hotels

# %%
import os
import json
from serpapi import GoogleSearch

# SerpApi 클라이언트를 초기화하기 위한 파라미터를 설정합니다.
# 검색어, 체크인/체크아웃 날짜, 인원수 등을 지정합니다.
params = {
    "engine": "google_hotels",
    "q": "서울 5성급 호텔",
    "check_in_date": "2025-10-24",
    "check_out_date": "2025-10-26",
    "adults": "2",
    "currency": "KRW",
    "hl": "ko",
    "api_key": os.getenv("SERPAPI_API_KEY")
}

# 파라미터를 사용하여 GoogleSearch 객체를 생성합니다.
search = GoogleSearch(params)

try:
    # 검색을 실행하고 결과를 딕셔너리 형태로 가져옵니다.
    results = search.get_dict()

    # 결과에 'properties' 키가 있는지 확인합니다.
    if "properties" in results:
        print("✅ 검색 성공! 호텔 정보를 출력합니다. (상위 5개)")
        
        # 상위 5개 호텔 정보만 추출하여 출력합니다.
        top_5_hotels = results["properties"][:5]
        
        # 가독성을 위해 JSON 형식으로 예쁘게 출력합니다.
        print(json.dumps(top_5_hotels, indent=2, ensure_ascii=False))

    elif "error" in results:
        print(f"❌ 검색 중 오류가 발생했습니다: {results['error']}")
    else:
        print("⚠️ 호텔 정보를 찾을 수 없습니다. 다른 검색어나 날짜로 시도해보세요.")
        print("\n전체 응답:")
        print(json.dumps(results, indent=2, ensure_ascii=False))

except Exception as e:
    print(f"스크립트 실행 중 예외가 발생했습니다: {e}")
# Out:
# ✅ 검색 성공! 호텔 정보를 출력합니다. (상위 5개)
# [
#   {
#     "type": "hotel",
#     "name": "그랜드 워커힐 서울",
#     "description": "고급 객실과 스위트룸을 갖춘 화려한 호텔로 레스토랑 5곳, 도서관, 골프 연습장, 수영장을 이용할 수 있습니다.",
#     "link": "https://www.walkerhill.com/grandwalkerhillseoul/",
#     "property_token": "ChgIjqncsL3gm5qsARoLL20vMDExam0yOGMQAQ",
#     "serpapi_property_details_link": "https://serpapi.com/search.json?adults=2&check_in_date=2025-10-24&check_out_date=2025-10-26&children=0&currency=KRW&engine=google_hotels&gl=us&hl=ko&property_token=ChgIjqncsL3gm5qsARoLL20vMDExam0yOGMQAQ&q=%EC%84%9C%EC%9A%B8+5%EC%84%B1%EA%B8%89+%ED%98%B8%ED%85%94",
#     "gps_coordinates": {
#       "latitude": 37.5552126,
#       "longitude": 127.11089050000001
#     },
#     "check_in_time": "오후 3:00",
#     "check_out_time": "오후 12:00",
#     "rate_per_night": {
#       "lowest": "₩274,568",
#       "extracted_lowest": 274568,
#       "before_taxes_fees": "₩249,607",
#       "extracted_before_taxes_fees": 249607
#     },
#     "total_rate": {
#       "lowest": "₩549,135",
#       "extracted_lowest": 549135,
#       "before_taxes_fees": "₩499,214",
#       "extracted_before_taxes_fees": 499214
#     },
#     "deal": "일반적인 가격 대비 19% 저렴",
#     "deal_description": "Deal",
#     "nearby_places": [
#       {
#         "name": "인천국제공항",
#         "transportations": [
#           {
#             "type": "Public transport",
#             "duration": "1시간 49분"
#           }
#         ]
#       },
#       {
#         "name": "자연에서 온 추어탕"
#       }
#     ],
#     "hotel_class": "5성급 호텔",
#     "extracted_hotel_class": 5,
#     "images": [
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/p/AF1QipPIEK3NGXNfX3xa3-NNyHFnerDh8qJEi-elgRXo=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://lh5.googleusercontent.com/p/AF1QipPIEK3NGXNfX3xa3-NNyHFnerDh8qJEi-elgRXo=s10000"
#       },
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/p/AF1QipM_bPEcxWItrfFDnsClj0LOho0Nugbg1aiZXh7F=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://lh5.googleusercontent.com/p/AF1QipM_bPEcxWItrfFDnsClj0LOho0Nugbg1aiZXh7F=s10000"
#       },
#       {
#         "thumbnail": "https://lh6.googleusercontent.com/proxy/M4qEGfrkwayOmx1pXHTkG4YfWg49DnrXqrSkgya46XTNXqM-w-BsGL-oR2BuOHoVWhTEti65Hmx8Ey7df4ZNax00_o38hYUggDN2ykEE1cBQu-eNrbIDNinsffi946p7hOPrt2aeR9NPoFqZllE0osxHu3W1JQ=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/16/0c/ff/7d/grand-walkerhill-seoul.jpg?w=1200&h=800&s=1"
#       },
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/p/AF1QipNod-Y_BaJD1Ia6t6h0kK8_c990A59RKISi8gEx=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://lh5.googleusercontent.com/p/AF1QipNod-Y_BaJD1Ia6t6h0kK8_c990A59RKISi8gEx=s10000"
#       },
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/p/AF1QipMFD_ChVGu0DncAeygvFexwcEWmaNAu5EUqOtJg=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://lh5.googleusercontent.com/p/AF1QipMFD_ChVGu0DncAeygvFexwcEWmaNAu5EUqOtJg=s10000"
#       },
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/p/AF1QipNCD6Xn_YEoN9zscPFhVIwO0aBKFX0FzRK9bLZW=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://lh5.googleusercontent.com/p/AF1QipNCD6Xn_YEoN9zscPFhVIwO0aBKFX0FzRK9bLZW=s10000"
#       },
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/p/AF1QipNbXbdX3ci4qrVPb7QUSLxeWbGS0qVQy5tgNb7j=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://lh5.googleusercontent.com/p/AF1QipNbXbdX3ci4qrVPb7QUSLxeWbGS0qVQy5tgNb7j=s10000"
#       },
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/p/AF1QipOjlwlkBuZrXLe9R4gt5KLYXa_aQ_sSMVIAkSSS=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://lh5.googleusercontent.com/p/AF1QipOjlwlkBuZrXLe9R4gt5KLYXa_aQ_sSMVIAkSSS=s10000"
#       },
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/p/AF1QipP5IyqZo-HP6EJymrgt0WGerpzk1NdDJMdSFGFr=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://lh5.googleusercontent.com/p/AF1QipP5IyqZo-HP6EJymrgt0WGerpzk1NdDJMdSFGFr=s10000"
#       }
#     ],
#     "overall_rating": 4.4,
#     "reviews": 3821,
#     "ratings": [
#       {
#         "stars": 5,
#         "count": 2405
#       },
#       {
#         "stars": 4,
#         "count": 948
#       },
#       {
#         "stars": 3,
#         "count": 290
#       },
#       {
#         "stars": 2,
#         "count": 78
#       },
#       {
#         "stars": 1,
#         "count": 100
#       }
#     ],
#     "location_rating": 3.7,
#     "reviews_breakdown": [
#       {
#         "name": "밤문화",
#         "description": "Nightlife",
#         "total_mentioned": 73,
#         "positive": 44,
#         "negative": 7,
#         "neutral": 22
#       },
#       {
#         "name": "자연",
#         "description": "Nature and outdoor activities",
#         "total_mentioned": 63,
#         "positive": 60,
#         "negative": 1,
#         "neutral": 2
#       },
#       {
#         "name": "특징",
#         "description": "Property",
#         "total_mentioned": 206,
#         "positive": 161,
#         "negative": 28,
#         "neutral": 17
#       },
#       {
#         "name": "바",
#         "description": "Bar or lounge",
#         "total_mentioned": 56,
#         "positive": 34,
#         "negative": 9,
#         "neutral": 13
#       },
#       {
#         "name": "서비스",
#         "description": "Service",
#         "total_mentioned": 149,
#         "positive": 116,
#         "negative": 21,
#         "neutral": 12
#       },
#       {
#         "name": "Dining",
#         "description": "Food and Beverage",
#         "total_mentioned": 88,
#         "positive": 63,
#         "negative": 11,
#         "neutral": 14
#       }
#     ],
#     "amenities": [
#       "Breakfast ($)",
#       "Free Wi-Fi",
#       "Free parking",
#       "Pools",
#       "Hot tub",
#       "Air conditioning",
#       "Fitness center",
#       "Spa",
#       "Bar",
#       "Restaurant",
#       "Room service",
#       "Full-service laundry",
#       "Accessible",
#       "Business center",
#       "Kid-friendly",
#       "Smoke-free property"
#     ]
#   },
#   {
#     "type": "hotel",
#     "name": "Grand Hyatt Seoul",
#     "description": "아이스링크, 야외 수영장이 있는 세련된 호텔로 2개의 바, 델리, 스파, 7개의 레스토랑을 이용할 수 있습니다.",
#     "link": "https://www.hyatt.com/grand-hyatt/en-US/selrs-grand-hyatt-seoul?src=corp_lclb_google_seo_selrs&utm_source=google&utm_medium=organic&utm_campaign=lmr",
#     "property_token": "ChYIrsPdy9qOlJIpGgovbS8wYndreTU3EAE",
#     "serpapi_property_details_link": "https://serpapi.com/search.json?adults=2&check_in_date=2025-10-24&check_out_date=2025-10-26&children=0&currency=KRW&engine=google_hotels&gl=us&hl=ko&property_token=ChYIrsPdy9qOlJIpGgovbS8wYndreTU3EAE&q=%EC%84%9C%EC%9A%B8+5%EC%84%B1%EA%B8%89+%ED%98%B8%ED%85%94",
#     "gps_coordinates": {
#       "latitude": 37.538987999999996,
#       "longitude": 126.9958415
#     },
#     "check_in_time": "오후 3:00",
#     "check_out_time": "오전 11:00",
#     "rate_per_night": {
#       "lowest": "₩688,381",
#       "extracted_lowest": 688381,
#       "before_taxes_fees": "₩568,920",
#       "extracted_before_taxes_fees": 568920
#     },
#     "total_rate": {
#       "lowest": "₩1,376,762",
#       "extracted_lowest": 1376762,
#       "before_taxes_fees": "₩1,137,840",
#       "extracted_before_taxes_fees": 1137840
#     },
#     "deal": "일반적인 가격 대비 24% 저렴",
#     "deal_description": "Deal",
#     "nearby_places": [
#       {
#         "name": "인천국제공항",
#         "transportations": [
#           {
#             "type": "Public transport",
#             "duration": "1시간 34분"
#           }
#         ]
#       },
#       {
#         "name": "한남김밥"
#       }
#     ],
#     "hotel_class": "5성급 호텔",
#     "extracted_hotel_class": 5,
#     "images": [
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/p/AF1QipPZTYKH0DcVIdtV-Tilpv1qBMxELc3FwIkSNNxZ=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://lh5.googleusercontent.com/p/AF1QipPZTYKH0DcVIdtV-Tilpv1qBMxELc3FwIkSNNxZ=s10000"
#       },
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/p/AF1QipPmvgc2A8eO1awwwEDwhT7nBAt5C73kT71f0ERQ=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://lh5.googleusercontent.com/p/AF1QipPmvgc2A8eO1awwwEDwhT7nBAt5C73kT71f0ERQ=s10000"
#       },
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/p/AF1QipO3GInDN0ca9X4necWpkb54vhguVD5Ty_uFYtFY=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://lh5.googleusercontent.com/p/AF1QipO3GInDN0ca9X4necWpkb54vhguVD5Ty_uFYtFY=s10000"
#       },
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/p/AF1QipOhooEOAqj2unaA1M4OE4ElLsBacFTRKCkAVgDv=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://lh5.googleusercontent.com/p/AF1QipOhooEOAqj2unaA1M4OE4ElLsBacFTRKCkAVgDv=s10000"
#       },
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/p/AF1QipOtRp-claY-rb_REK6H9HXInMKzEFMsE_Wozrhb=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://lh5.googleusercontent.com/p/AF1QipOtRp-claY-rb_REK6H9HXInMKzEFMsE_Wozrhb=s10000"
#       },
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/p/AF1QipMW0p8HweeK7CZ7es0BRoEV7vBZicdIxIdgqSPw=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://lh5.googleusercontent.com/p/AF1QipMW0p8HweeK7CZ7es0BRoEV7vBZicdIxIdgqSPw=s10000"
#       },
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/gps-cs-s/AC9h4nqVOba3J0btytdu54OcEnZTija5DcTLJQZLs97whjg04DeAx6ykW3X17eCTWXMBZmaWH-tAMqwhW_Nr7VczyA2RSEi-JCG3AqkMXn2fFc1svtcAekGsulNUx-zPmHDL3FvI2SQQB4is34s=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://lh5.googleusercontent.com/p/CIABIhCgsXsMRvyzTKZsG5ZDKu_4=s10000"
#       },
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/gps-cs-s/AC9h4nrLgJSVrmcod53t2xYLGMozgS8rCl1xoWd8Mi5mN4p48ZUmJgvbx3ZTxt8fNhdm6ULTUgqbcPhgBsant-No1_W2d7uGn69SG5YpYD9cTsp3Iae2lyYrof-xhN1CenhapOzA-C_UGA=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://lh5.googleusercontent.com/p/CIHM0ogKEICAgIC4pdLr1AE=s10000"
#       },
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/p/AF1QipNYfQCzL2WiVIlAymSv_PJrxXFyJAMLbsYuGXy_=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://lh5.googleusercontent.com/p/AF1QipNYfQCzL2WiVIlAymSv_PJrxXFyJAMLbsYuGXy_=s10000"
#       }
#     ],
#     "overall_rating": 4.4,
#     "reviews": 8322,
#     "ratings": [
#       {
#         "stars": 5,
#         "count": 5287
#       },
#       {
#         "stars": 4,
#         "count": 2039
#       },
#       {
#         "stars": 3,
#         "count": 562
#       },
#       {
#         "stars": 2,
#         "count": 163
#       },
#       {
#         "stars": 1,
#         "count": 271
#       }
#     ],
#     "location_rating": 3.8,
#     "reviews_breakdown": [
#       {
#         "name": "특징",
#         "description": "Property",
#         "total_mentioned": 738,
#         "positive": 562,
#         "negative": 107,
#         "neutral": 69
#       },
#       {
#         "name": "서비스",
#         "description": "Service",
#         "total_mentioned": 548,
#         "positive": 428,
#         "negative": 92,
#         "neutral": 28
#       },
#       {
#         "name": "피트니스",
#         "description": "Fitness",
#         "total_mentioned": 193,
#         "positive": 146,
#         "negative": 30,
#         "neutral": 17
#       },
#       {
#         "name": "객실",
#         "description": "Room amenities",
#         "total_mentioned": 382,
#         "positive": 290,
#         "negative": 43,
#         "neutral": 49
#       },
#       {
#         "name": "바",
#         "description": "Bar or lounge",
#         "total_mentioned": 218,
#         "positive": 142,
#         "negative": 48,
#         "neutral": 28
#       },
#       {
#         "name": "자연",
#         "description": "Nature and outdoor activities",
#         "total_mentioned": 139,
#         "positive": 131,
#         "negative": 1,
#         "neutral": 7
#       }
#     ],
#     "amenities": [
#       "Breakfast ($)",
#       "Free Wi-Fi",
#       "Free parking",
#       "Pool",
#       "Air conditioning",
#       "Fitness center",
#       "Spa",
#       "Bar",
#       "Restaurant",
#       "Room service",
#       "Full-service laundry",
#       "Accessible",
#       "Business center",
#       "Kid-friendly",
#       "Smoke-free property"
#     ]
#   },
#   {
#     "type": "hotel",
#     "name": "서울신라호텔",
#     "description": "현대적인 객실과 스위트룸을 갖춘 고급 호텔로 헬스장, 스파, 루프탑 수영장, 고급 레스토랑을 이용할 수 있습니다.",
#     "link": "http://www.shilla.net/seoul/",
#     "property_token": "ChcI8aaM99KzpvZJGgsvZy8xdGR5bnF3eBAB",
#     "serpapi_property_details_link": "https://serpapi.com/search.json?adults=2&check_in_date=2025-10-24&check_out_date=2025-10-26&children=0&currency=KRW&engine=google_hotels&gl=us&hl=ko&property_token=ChcI8aaM99KzpvZJGgsvZy8xdGR5bnF3eBAB&q=%EC%84%9C%EC%9A%B8+5%EC%84%B1%EA%B8%89+%ED%98%B8%ED%85%94",
#     "gps_coordinates": {
#       "latitude": 37.5559034,
#       "longitude": 127.0052509
#     },
#     "check_in_time": "오후 3:00",
#     "check_out_time": "오전 11:00",
#     "rate_per_night": {
#       "lowest": "₩771,343",
#       "extracted_lowest": 771343,
#       "before_taxes_fees": "₩701,224",
#       "extracted_before_taxes_fees": 701224
#     },
#     "total_rate": {
#       "lowest": "₩1,542,686",
#       "extracted_lowest": 1542686,
#       "before_taxes_fees": "₩1,402,448",
#       "extracted_before_taxes_fees": 1402448
#     },
#     "nearby_places": [
#       {
#         "name": "인천국제공항",
#         "transportations": [
#           {
#             "type": "Public transport",
#             "duration": "1시간 41분"
#           }
#         ]
#       },
#       {
#         "name": "팔팔식당"
#       }
#     ],
#     "hotel_class": "5성급 호텔",
#     "extracted_hotel_class": 5,
#     "images": [
#       {
#         "thumbnail": "https://lh6.googleusercontent.com/proxy/IpT6nsjDLzsKxxiNTs92ZOFxX1MPINemAz6CmEDgjE0KiuwJK-tm6438rte4guWNTVu-4AfO3-uV8up4PjwneOz6GtIlHgNbneXrv0qVol1wIDnFZLp9QK84phB3tS18LIqcf1Z0wF3pSoH6ZhaClJW1qT3XrRM=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://d2hyz2bfif3cr8.cloudfront.net/imageRepo/4/0/59/903/318/Standard_Business_Deluxe_04_LO_S.jpg"
#       },
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/proxy/cKTVhkMW6veVji5ONLkBezXN6e-9BYFuZPbSOuACQ_ACde_80mmOk3v-qxrk4-HXVQbUwEhmJoVdj2eSXXVciredxsVbDRvyH52rFDnS3T-qPFO5lGxWb-5Jtj_o3KJjJYOQMtl4gaPT94727e-gqchvMmhijkI=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://images.trvl-media.com/lodging/1000000/20000/15100/15031/1ddb1c6d_z.jpg"
#       },
#       {
#         "thumbnail": "https://lh5.googleusercontent.com/proxy/MN7LkhtK56BY0vQFOcSkvF8A8foLlrbYle2JeH3HDGfekps0oQwq7tXoXhuxW5oWrz-TzrQXKZNr4WEb60saYZLE2nr_W8PExB4U7L575-JiGXeH8VVrj3Wnw8JYdp45XDQBW2q768mZ1IQICW7Q866G-KKOSFA=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://d2hyz2bfif3cr8.cloudfront.net/imageRepo/3/0/179/429/361/The_Shilla_Seoul_Urban_day_S.jpg"
#       },
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/p/AF1QipNIwuhvebc0wJeiNAyB58TG6lJOXfenmpaD39k=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://lh5.googleusercontent.com/p/AF1QipNIwuhvebc0wJeiNAyB58TG6lJOXfenmpaD39k=s10000"
#       },
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/p/AF1QipMxFMkEpqE6LmHRyN_9U3WqMSIdq12KPGwbsn4=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://lh5.googleusercontent.com/p/AF1QipMxFMkEpqE6LmHRyN_9U3WqMSIdq12KPGwbsn4=s10000"
#       },
#       {
#         "thumbnail": "https://lh5.googleusercontent.com/proxy/VPO0dYlHA5ySJkHpJlvfF1q3ecUD9FUKo_uo_d3hy_rQcMLImxUDc_f8flRT2ljFUUJaPY0s2N2V1IxK3to8c0o4ZSAkbEqZUCBS5MflkAAqBR7FBkugSJ9FGzanqCV4RfenIcsVvJh_yj4s-bXWeD2DqNd2tQ=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://d2hyz2bfif3cr8.cloudfront.net/imageRepo/4/0/57/313/0/Dynasty_Hall_Wedding_S.jpg"
#       },
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/p/AF1QipP2Sy62GzjjdqPNGfNTug7Jg1zcUkr2bSlzFhA=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://lh5.googleusercontent.com/p/AF1QipP2Sy62GzjjdqPNGfNTug7Jg1zcUkr2bSlzFhA=s10000"
#       },
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/p/AF1QipPFELPGJqt182d2OWbmXg4eUp4i9ttoGnakWiBS=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://lh5.googleusercontent.com/p/AF1QipPFELPGJqt182d2OWbmXg4eUp4i9ttoGnakWiBS=s10000"
#       },
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/p/AF1QipPSZ5OCzfFDTtcLkJmrUxjXa5cDafQK0z9Ln8M=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://lh5.googleusercontent.com/p/AF1QipPSZ5OCzfFDTtcLkJmrUxjXa5cDafQK0z9Ln8M=s10000"
#       }
#     ],
#     "overall_rating": 4.6,
#     "reviews": 7351,
#     "ratings": [
#       {
#         "stars": 5,
#         "count": 5344
#       },
#       {
#         "stars": 4,
#         "count": 1383
#       },
#       {
#         "stars": 3,
#         "count": 366
#       },
#       {
#         "stars": 2,
#         "count": 91
#       },
#       {
#         "stars": 1,
#         "count": 167
#       }
#     ],
#     "location_rating": 3.3,
#     "reviews_breakdown": [
#       {
#         "name": "서비스",
#         "description": "Service",
#         "total_mentioned": 519,
#         "positive": 430,
#         "negative": 56,
#         "neutral": 33
#       },
#       {
#         "name": "특징",
#         "description": "Property",
#         "total_mentioned": 600,
#         "positive": 497,
#         "negative": 49,
#         "neutral": 54
#       },
#       {
#         "name": "피트니스",
#         "description": "Fitness",
#         "total_mentioned": 147,
#         "positive": 101,
#         "negative": 29,
#         "neutral": 17
#       },
#       {
#         "name": "Dining",
#         "description": "Food and Beverage",
#         "total_mentioned": 241,
#         "positive": 176,
#         "negative": 38,
#         "neutral": 27
#       },
#       {
#         "name": "주차",
#         "description": "Parking",
#         "total_mentioned": 126,
#         "positive": 28,
#         "negative": 74,
#         "neutral": 24
#       },
#       {
#         "name": "바",
#         "description": "Bar or lounge",
#         "total_mentioned": 129,
#         "positive": 93,
#         "negative": 21,
#         "neutral": 15
#       }
#     ],
#     "amenities": [
#       "Breakfast ($)",
#       "Free Wi-Fi",
#       "Free parking",
#       "Pools",
#       "Hot tub",
#       "Air conditioning",
#       "Fitness center",
#       "Spa",
#       "Bar",
#       "Restaurant",
#       "Room service",
#       "Full-service laundry",
#       "Accessible",
#       "Business center",
#       "Kid-friendly",
#       "Smoke-free property"
#     ]
#   },
#   {
#     "type": "hotel",
#     "name": "비스타 워커힐 서울",
#     "description": "실내 수영장, 스파, DJ가 있는 바, 한강 전망의 식당을 이용할 수 있는 세련된 호텔입니다.",
#     "link": "https://www.walkerhill.com/vistawalkerhillseoul",
#     "property_token": "ChcIocSijq-QkcRfGgsvZy8xdHlrczliehAB",
#     "serpapi_property_details_link": "https://serpapi.com/search.json?adults=2&check_in_date=2025-10-24&check_out_date=2025-10-26&children=0&currency=KRW&engine=google_hotels&gl=us&hl=ko&property_token=ChcIocSijq-QkcRfGgsvZy8xdHlrczliehAB&q=%EC%84%9C%EC%9A%B8+5%EC%84%B1%EA%B8%89+%ED%98%B8%ED%85%94",
#     "gps_coordinates": {
#       "latitude": 37.5543699,
#       "longitude": 127.1112096
#     },
#     "check_in_time": "오후 3:00",
#     "check_out_time": "오후 12:00",
#     "rate_per_night": {
#       "lowest": "₩419,583",
#       "extracted_lowest": 419583,
#       "before_taxes_fees": "₩346,764",
#       "extracted_before_taxes_fees": 346764
#     },
#     "total_rate": {
#       "lowest": "₩839,166",
#       "extracted_lowest": 839166,
#       "before_taxes_fees": "₩693,527",
#       "extracted_before_taxes_fees": 693527
#     },
#     "nearby_places": [
#       {
#         "name": "인천국제공항",
#         "transportations": [
#           {
#             "type": "Public transport",
#             "duration": "1시간 48분"
#           }
#         ]
#       },
#       {
#         "name": "듀블럭 Dewblock"
#       }
#     ],
#     "hotel_class": "5성급 호텔",
#     "extracted_hotel_class": 5,
#     "images": [
#       {
#         "thumbnail": "https://lh6.googleusercontent.com/proxy/wNOnxtUk4KPBeDp6i7nXZRin8WkeuoACxogQhiVs-u8BWk5ZU2i2QcqcYmTCoYUUC8di7n8TIKA-X_w-FzacYKYEvfK8kw1m86Gc6Htjn_kQfWH7TVg6BqQ4pfs1GV_47iWwHbsdTY_13ObZuVHBfckKPQ_efg=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://cdn.worldota.net/t/1024x768/content/6d/0b/6d0b81da6257ee3b0ce23715855d32899249eef4.jpeg"
#       },
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/p/AF1QipOJB5FuUR5FulXZQ2l9MW4IwACNZy8cgglh0i8=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://lh5.googleusercontent.com/p/AF1QipOJB5FuUR5FulXZQ2l9MW4IwACNZy8cgglh0i8=s10000"
#       },
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/p/AF1QipOtgLnYIyczIdcwvnLvS3kcHiLwz6BKqH2kmDo=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://lh5.googleusercontent.com/p/AF1QipOtgLnYIyczIdcwvnLvS3kcHiLwz6BKqH2kmDo=s10000"
#       },
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/p/AF1QipMOUHpHVxdyaYH3_JD3e4mTxW2XmJH4f5Oz4Wg=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://lh5.googleusercontent.com/p/AF1QipMOUHpHVxdyaYH3_JD3e4mTxW2XmJH4f5Oz4Wg=s10000"
#       },
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/gps-cs-s/AC9h4npVz1BWldWSJnn8C-UicO2ofy2C0oqA_VrQF_z2QTVrcA66VD4DDcSKPrSgVHggwsDw_HRZKI4-X7RB_dHHRRiJeRzs9R3-DDy-kaXTWrp27Ry4CZd9DHLzLbEnSE53ofjHdOiIyA=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://lh5.googleusercontent.com/p/CIHM0ogKEICAgIDaj4DWhwE=s10000"
#       },
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/p/AF1QipPKImzQ2Hwlwwa-IHadMIehrDT8iu7cJg2eHlc=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://lh5.googleusercontent.com/p/AF1QipPKImzQ2Hwlwwa-IHadMIehrDT8iu7cJg2eHlc=s10000"
#       },
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/p/AF1QipNouqIFRQo9sEmtjIPdfz_yRG69kMMSHx3dXF8=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://lh5.googleusercontent.com/p/AF1QipNouqIFRQo9sEmtjIPdfz_yRG69kMMSHx3dXF8=s10000"
#       },
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/p/AF1QipOW3yJD_jXFJOGc15vjRT5TH7m0I1bc46dxST4=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://lh5.googleusercontent.com/p/AF1QipOW3yJD_jXFJOGc15vjRT5TH7m0I1bc46dxST4=s10000"
#       },
#       {
#         "thumbnail": "https://lh4.googleusercontent.com/proxy/oYL3TyTlrbpWVetv_MmbAwrocUlQ2j7V2B3JENWAAJBnrkMJngsEmb-Mib841MTUfDbCGvFfEnes1J3bmLXmYcVuKdMItNWUy7usc7iCxeUCHhUmllNdguG5o0SGC3hrgXLy7Uqh4LiMuN3dCmXL8XzcaFqBHg=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://images.trvl-media.com/lodging/18000000/17920000/17917400/17917315/d2ad307d_z.jpg"
#       }
#     ],
#     "overall_rating": 4.5,
#     "reviews": 2167,
#     "ratings": [
#       {
#         "stars": 5,
#         "count": 1464
#       },
#       {
#         "stars": 4,
#         "count": 517
#       },
#       {
#         "stars": 3,
#         "count": 131
#       },
#       {
#         "stars": 2,
#         "count": 16
#       },
#       {
#         "stars": 1,
#         "count": 39
#       }
#     ],
#     "location_rating": 3.7,
#     "reviews_breakdown": [
#       {
#         "name": "자연",
#         "description": "Nature and outdoor activities",
#         "total_mentioned": 62,
#         "positive": 58,
#         "negative": 1,
#         "neutral": 3
#       },
#       {
#         "name": "피트니스",
#         "description": "Fitness",
#         "total_mentioned": 48,
#         "positive": 34,
#         "negative": 8,
#         "neutral": 6
#       },
#       {
#         "name": "객실",
#         "description": "Room amenities",
#         "total_mentioned": 96,
#         "positive": 75,
#         "negative": 12,
#         "neutral": 9
#       },
#       {
#         "name": "수영장",
#         "description": "Pool",
#         "total_mentioned": 30,
#         "positive": 20,
#         "negative": 5,
#         "neutral": 5
#       },
#       {
#         "name": "특징",
#         "description": "Property",
#         "total_mentioned": 124,
#         "positive": 103,
#         "negative": 12,
#         "neutral": 9
#       },
#       {
#         "name": "웰니스",
#         "description": "Wellness",
#         "total_mentioned": 24,
#         "positive": 19,
#         "negative": 1,
#         "neutral": 4
#       }
#     ],
#     "amenities": [
#       "Breakfast ($)",
#       "Free Wi-Fi",
#       "Free parking",
#       "Pool",
#       "Hot tub",
#       "Air conditioning",
#       "Fitness center",
#       "Spa",
#       "Bar",
#       "Restaurant",
#       "Room service",
#       "Full-service laundry",
#       "Accessible",
#       "Business center",
#       "Kid-friendly",
#       "Smoke-free property"
#     ]
#   },
#   {
#     "type": "hotel",
#     "name": "포시즌스 호텔 서울",
#     "description": "스타일리시한 객실과 스위트룸을 갖춘 고급 호텔로 3곳의 수영장, 헬스장, 스파, 레스토랑, 바를 이용할 수 있습니다.",
#     "link": "https://www.fourseasons.com/seoul/?utm_source=google&utm_medium=organicsearch&utm_campaign=tor-sko-hre-mid-seo-na&utm_content=na-na&utm_term=na",
#     "property_token": "ChoI-sLC4J76rIy8ARoNL2cvMTFidzQ2aHkyMBAB",
#     "serpapi_property_details_link": "https://serpapi.com/search.json?adults=2&check_in_date=2025-10-24&check_out_date=2025-10-26&children=0&currency=KRW&engine=google_hotels&gl=us&hl=ko&property_token=ChoI-sLC4J76rIy8ARoNL2cvMTFidzQ2aHkyMBAB&q=%EC%84%9C%EC%9A%B8+5%EC%84%B1%EA%B8%89+%ED%98%B8%ED%85%94",
#     "gps_coordinates": {
#       "latitude": 37.5706978,
#       "longitude": 126.9755073
#     },
#     "check_in_time": "오후 3:00",
#     "check_out_time": "오후 12:00",
#     "rate_per_night": {
#       "lowest": "₩1,065,198",
#       "extracted_lowest": 1065198,
#       "before_taxes_fees": "₩973,936",
#       "extracted_before_taxes_fees": 973936
#     },
#     "total_rate": {
#       "lowest": "₩2,130,396",
#       "extracted_lowest": 2130396,
#       "before_taxes_fees": "₩1,947,872",
#       "extracted_before_taxes_fees": 1947872
#     },
#     "deal": "일반적인 가격 대비 17% 저렴",
#     "deal_description": "Deal",
#     "nearby_places": [
#       {
#         "name": "청계천",
#         "transportations": [
#           {
#             "type": "Public transport",
#             "duration": "7분"
#           }
#         ]
#       },
#       {
#         "name": "인천국제공항",
#         "transportations": [
#           {
#             "type": "Public transport",
#             "duration": "1시간 29분"
#           }
#         ]
#       },
#       {
#         "name": "무탄 광화문점(MUTAN Gwanghwamun)",
#         "transportations": [
#           {
#             "type": "Public transport",
#             "duration": "6분"
#           }
#         ]
#       }
#     ],
#     "hotel_class": "5성급 호텔",
#     "extracted_hotel_class": 5,
#     "images": [
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/p/AF1QipNJzBo1hwHY1QfEz9qmwRhyzBOJuYt61OPH-im6=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://lh5.googleusercontent.com/p/AF1QipNJzBo1hwHY1QfEz9qmwRhyzBOJuYt61OPH-im6=s10000"
#       },
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/p/AF1QipOelE7A1jSevP2kSLZZMO8IVqnLCjtef2bxo1Zf=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://lh5.googleusercontent.com/p/AF1QipOelE7A1jSevP2kSLZZMO8IVqnLCjtef2bxo1Zf=s10000"
#       },
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/p/AF1QipP6q1iIDtvxLA6drIpPFH22k_YxZqg-7qDePFtx=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://lh5.googleusercontent.com/p/AF1QipP6q1iIDtvxLA6drIpPFH22k_YxZqg-7qDePFtx=s10000"
#       },
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/p/AF1QipNI7TMObkiLIsnDEtjorLd0_0v0g2I_niLbN1wK=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://lh5.googleusercontent.com/p/AF1QipNI7TMObkiLIsnDEtjorLd0_0v0g2I_niLbN1wK=s10000"
#       },
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/p/AF1QipPfb2fm3Auv1RECirtKNIuwufFF3-xx2FnLB5yg=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://lh5.googleusercontent.com/p/AF1QipPfb2fm3Auv1RECirtKNIuwufFF3-xx2FnLB5yg=s10000"
#       },
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/p/AF1QipMPFbTcT1oiDh4czm_G7reFiek8FO9vfwPXv2jt=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://lh5.googleusercontent.com/p/AF1QipMPFbTcT1oiDh4czm_G7reFiek8FO9vfwPXv2jt=s10000"
#       },
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/p/AF1QipNcClAzAdqWQDLphN_a6xxx4dHa68Y7VlVyXIH5=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://lh5.googleusercontent.com/p/AF1QipNcClAzAdqWQDLphN_a6xxx4dHa68Y7VlVyXIH5=s10000"
#       },
#       {
#         "thumbnail": "https://lh5.googleusercontent.com/proxy/rHgVjw4DDgA8fqzOvTKjPf6V3ctNHpPsdKJrpRKmqc0Ay4rQqF6RkcUTWER2IUi1T0TtCw5PaEnbN7IDImAYUHqMD2j1QkBLn2QxJw-JgS6OY3eEsfEXQabEStoE71vIOL6JEzi3ahIilymMUdYiCn4c2otBSw=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://images.trvl-media.com/lodging/12000000/11920000/11918400/11918302/017727d8_z.jpg"
#       },
#       {
#         "thumbnail": "https://lh3.googleusercontent.com/p/AF1QipMxlk3yC2KFbK46ifcijXiSxyL69FwLDEPAE8se=s287-w287-h192-n-k-no-v1",
#         "original_image": "https://lh5.googleusercontent.com/p/AF1QipMxlk3yC2KFbK46ifcijXiSxyL69FwLDEPAE8se=s10000"
#       }
#     ],
#     "overall_rating": 4.6,
#     "reviews": 7091,
#     "ratings": [
#       {
#         "stars": 5,
#         "count": 4959
#       },
#       {
#         "stars": 4,
#         "count": 1471
#       },
#       {
#         "stars": 3,
#         "count": 422
#       },
#       {
#         "stars": 2,
#         "count": 98
#       },
#       {
#         "stars": 1,
#         "count": 141
#       }
#     ],
#     "location_rating": 4.3,
#     "reviews_breakdown": [
#       {
#         "name": "서비스",
#         "description": "Service",
#         "total_mentioned": 637,
#         "positive": 546,
#         "negative": 54,
#         "neutral": 37
#       },
#       {
#         "name": "특징",
#         "description": "Property",
#         "total_mentioned": 656,
#         "positive": 561,
#         "negative": 48,
#         "neutral": 47
#       },
#       {
#         "name": "Dining",
#         "description": "Food and Beverage",
#         "total_mentioned": 313,
#         "positive": 237,
#         "negative": 30,
#         "neutral": 46
#       },
#       {
#         "name": "바",
#         "description": "Bar or lounge",
#         "total_mentioned": 189,
#         "positive": 147,
#         "negative": 18,
#         "neutral": 24
#       },
#       {
#         "name": "피트니스",
#         "description": "Fitness",
#         "total_mentioned": 125,
#         "positive": 102,
#         "negative": 8,
#         "neutral": 15
#       },
#       {
#         "name": "웰니스",
#         "description": "Wellness",
#         "total_mentioned": 79,
#         "positive": 63,
#         "negative": 9,
#         "neutral": 7
#       }
#     ],
#     "amenities": [
#       "Breakfast ($)",
#       "Free Wi-Fi",
#       "Free parking",
#       "Indoor pool",
#       "Hot tub",
#       "Air conditioning",
#       "Pet-friendly",
#       "Fitness center",
#       "Spa",
#       "Bar",
#       "Restaurant",
#       "Room service",
#       "Airport shuttle",
#       "Golf",
#       "Full-service laundry",
#       "Accessible",
#       "Business center",
#       "Kid-friendly"
#     ],
#     "eco_certified": true
#   }
# ]
