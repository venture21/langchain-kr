# %%
from dotenv import load_dotenv

# .env 파일에서 환경 변수를 불러옵니다.
# OPENAI_API_KEY가 .env 파일에 설정되어 있어야 합니다.
load_dotenv()
# Out:
# True

# %%
from serpapi import GoogleSearch

search_keyword = "상일동역 맛집"

params = {
    "engine": "naver",
    "query": search_keyword,
    "api_key": "82af2a26a893c2969e972a0e068a5e847f58972fc422b5a61fb31f5209bc1086",
}

search = GoogleSearch(params)
results = search.get_dict()
results
# Out:
# {'search_metadata': {'id': '68a58ff21dcfe2d9c93cc578',
#   'status': 'Success',
#   'json_endpoint': 'https://serpapi.com/searches/33d1b1ed5212a2f8/68a58ff21dcfe2d9c93cc578.json',
#   'created_at': '2025-08-20 09:05:54 UTC',
#   'processed_at': '2025-08-20 09:05:54 UTC',
#   'naver_url': 'https://search.naver.com/search.naver?query=%EC%83%81%EC%9D%BC%EB%8F%99%EC%97%AD+%EB%A7%9B%EC%A7%91',
#   'raw_html_file': 'https://serpapi.com/searches/33d1b1ed5212a2f8/68a58ff21dcfe2d9c93cc578.html',
#   'total_time_taken': 2.24},
#  'search_parameters': {'query': '상일동역 맛집',
#   'engine': 'naver',
#   'device': 'desktop'},
#  'related_results': [{'position': 1,
#    'title': '상일동역 맛집 세민수산',
#    'link': 'https://search.naver.com/search.naver?where=nexearch&ssc=tab.nx.all&query=%EC%83%81%EC%9D%BC%EB%8F%99%EC%97%AD+%EB%A7%9B%EC%A7%91+%EC%84%B8%EB%AF%BC%EC%88%98%EC%82%B0&sm=tab_she&qdt=0'},
#   {'position': 2,
#    'title': '상일동역',
#    'link': 'https://search.naver.com/search.naver?where=nexearch&ssc=tab.nx.all&query=%EC%83%81%EC%9D%BC%EB%8F%99%EC%97%AD&sm=tab_she&qdt=0'},
#   {'position': 3,
#    'title': '고덕역 맛집',
#    'link': 'https://search.naver.com/search.naver?where=nexearch&ssc=tab.nx.all&query=%EA%B3%A0%EB%8D%95%EC%97%AD+%EB%A7%9B%EC%A7%91&sm=tab_she&qdt=0'}],
#  'ads_results': [{'title': '구워주는 양갈비 맛집 양미당',
#    'site': 'map.naver.com/v5',
#    'link': 'https://ader.naver.com/v1/_4r0_oL9IGSNu1rzW4aM0nwPglT_cf6cuk3-Neb2WRE9QjBimXKcUsh4ubemVs0bLTB6ZknC8OEUM3ttnHQAJrpa_zDHEL6GIDhBcJ-uCwk5bXFsgp3ARnsgdl5A3O7j9zEabGJRBqNCWMW4cyEt4uLHvTSrCjWwWcsuWF9errw9dFUcwpGjKedYkJTr6P7vcHjU_GT9xdZP9nMpw-goyXccjierVJFfYyWwOrDkOWP06Ax9XrrsYnSUUV9k6ywmClBZnzta60R28i4rS97_zg==?c=naver.search.pc.plsearch&t=0',
#    'thumbnail': 'https://searchad-phinf.pstatic.net/MjAyNTA1MDRfMzIg/MDAxNzQ2Mjk3NTMxNTE5.qPCs3XAMzY8Ur3auQ-H9WPSEj5c8R7pak24XKa9jNEcg.iXtYo-QQBPRGW4gcfa4RdUlkJhiJMqQOv0YV_EkwMFcg.JPEG/2942641-d0886406-011a-41c3-86a7-9f260eea806d.jpg?type=f160_160'},
#   {'title': '1등급한돈 고반식당상일동역점',
#    'site': 'm.place.naver.com/restaurant',
#    'link': 'https://ader.naver.com/v1/_4r0_oL9IGSNu1rzW4aM0nwPglT_cf6cuk3-Neb2WRE9QjBimXKcUsh4ubemVs0blfGDGvOIG9PKsSNz5_OVbpEoP2Asqy7L2l43u1eR-jjM1h01t_Dm_1DpOwju-lmDrmuiHSI_w7fNIUicp4sBi6wjiISXPKVDnj7E74zY8aydflkKX50_fTq-O7Yu9tuuNSsbBvJasobfM7LeFOW1r7WdvNiRLG3hjnouVeDh_VGsASbOsVCLHajF1PXnHIeRlUSthLcyKHCmWICl-A1lbw==?c=naver.search.pc.plsearch&t=0',
 'https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyNTA4MDFfMTgy%2FMDAxNzU0MDUwNjc4ODY5.HWNHhGxFmAyuOg31fruzSohPI-6OZL1PGz0LdsDU0eQg.BwhKyDFuQHrPLCes1O-XrIL9duvJX7TbTTS_wKAijQYg.JPEG%2F19.jpg%233000x2115&type=ff192_192'},
#   {'position': 6},
#   {'position': 7,
#    'title': '상일동역 맛집 ★ 어반나이프 ★ (feat. 슈바인학센)',
#    'source_icon': 'https://search.pstatic.net/common/?src=http%3A%2F%2Fblogpfthumb.phinf.naver.net%2FMjAyNTAxMTNfNCAg%2FMDAxNzM2NzQ5MTc3ODE3.V3sNxejAhHtF8HoN6YSuCItYexrKXorrVSPMG-iuVucg.faLAHgN1WFlTcqj3aTQa47DrobME2LhOGqrsM7l48N8g.JPEG%2FprofileImage.jpg&type=f54_54',
#    'source': '코코앨리스',
#    'link': 'https://blog.naver.com/eileenhur81/223875743965',
#    'snippet': '역시 상일동역 맛집이자 데이트 즐기기 좋은 스테이크 맛집답게 내부는 통창으로 시원하고 깔끔한 인테리어가 돋보였고 미리 예약을 해서 아늑한 분위기의 자리로 마련해 주셨어요. 소파 자리만 봐도 상일동 데이트 코스로 추천하는 이유! 편안하고 독립된 공간이라 지인과 대화하기도 좋고 음식에 편안하게 집중할 수 있었어요. 상일동역 맛집으로 소문난 이유가...',
#    'thumbnail': 'https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyNTA1MjNfNjgg%2FMDAxNzQ4MDA0NTUxOTcy.nEcxZFKEboJO1ZQddkKBl4JRjwuOTpHp1MoPNgFAlzwg.lg9YfiELJlxv0DO7zxNJPNug0d33mPG8_gfUjINtPgQg.PNG%2F%25C1%25A6%25B8%25F1%25C0%25BB-%25C0%25D4%25B7%25C2%25C7%25D8%25C1%25D6%25BC%25BC%25BF%25E4_-001_%252878%2529.png%231080x1080&type=ff192_192'},
#   {'position': 8},
#   {'position': 9},
#   {'position': 10},
#   {'position': 11,
#    'title': '상일동역 맛집 고반식당 구워주는 고기 편하게 먹자',
#    'source_icon': 'https://search.pstatic.net/common/?src=http%3A%2F%2Fblogpfthumb.phinf.naver.net%2FMjAyMzA0MjlfMjAw%2FMDAxNjgyNzM0OTQzMzA5.ogpekuBs0vWN1kIPxnmSS5LE0wWiW5Ktb6uinfxXa8Eg.kLyCk-y2unrBnMEcqqy0_mnfd6vJ1j2-DG4h5_Vp9Acg.GIF.lslsls7%2Fanigif.gif%2Fanigif.gif&type=f54_54',
#    'source': '건강하게 당질제한식',
#    'link': 'https://blog.naver.com/lslsls7/223976594052',
#    'snippet': '상일동역 맛집 고반식당은 상일동역 4번 출구에서 도보로 단 2~3분 거리에 있어 접근성이 뛰어나다. 강일역에서도 도보 5분 컷이다. 식당 깔끔하고 분위기 좋고 맛있는 고기 남이 구워주고 기본 상차림이 알차니 고반식당은 한 번쯤 가보기를 추천한다. <주소> 서울특별시 강동구 고덕로399 고덕센트럴푸르지오 메가스퀘어동 1층 132호 <전화번호> 0507-1342-4894 <영업시간...',
#    'thumbnail': 'https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyNTA4MTlfMTI1%2FMDAxNzU1NTY5OTU0MDA3.1veNIMdc347y6lsIZ5yfSZ_fOJTPk58ucPWthTMjV7og.lfZKZ2BSdjObhyNQl9sfEBVWjNv10yH9j7Ktc7UlR6Ag.JPEG%2FIMG%25A3%25DF4779.JPG%23900x1200&type=ff192_192'},
#   {'position': 12},
#   {'position': 13,
#    'title': '상일동역 근처 햄버거, 빙수, 치킨 맛집이에요. (제기준)',
#    'source_icon': 'https://search.pstatic.net/common/?src=http%3A%2F%2Fcafefiles.naver.net%2FMjAyMzAyMTBfMjY5%2FMDAxNjc1OTg3MDA0MDIy.tq1PQtWqC-_qHkv2x3rU4E9Rl0dGuGNZ6uvO-saCejIg.Yw5VlmTjehmuqNlEnkVrFUI2LwEmRasYyxNIy46Wj14g.PNG%2FKakaoTalk_20230210_023129538_14.png&type=f54_54',
#    'source': '송강맘 ♥ 송파맘 강동맘 맘카페 - 송파구 강동구 잠실맘 위례맘',
#    'link': 'https://cafe.naver.com/everyhomework/896727?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImV2ZXJ5aG9tZXdvcmsiLCJhcnRpY2xlSWQiOjg5NjcyNywiaXNzdWVkQXQiOjE3NTU2ODA3NTU0NzV9.TCrwdxdy7VZHV2bpTPv6khBzJw_9PYniyNDvspsKCfs',
#    'snippet': '저는 엄청 맛집을 찾아다니지는 않지만 맛있는 음식을 좋아해요 햄버거는 케이리치버거 라고 원래 삼성엔지니어링 근처에 있었는데 고덕비즈밸리 쪽으로 옮겼더라구요 배달은... 사장님은 그대로인 것 같아요 후라이드가 제일 맛있고 다른 맛들도 기본은 한데 저렴하기까지 하고 양도 많아요 다른 분들의 상일동역 맛집도 궁금해요 맛있는 것 많이 드시고 좋은 하루 되세요'},
#   {'position': 14,
#    'title': '상일동역 맛집 고덕동 맛집 푼푼 왕돈까스',
#    'source_icon': 'https://search.pstatic.net/common/?src=http%3A%2F%2Fblogpfthumb.phinf.naver.net%2F20120214_171%2Fonion03111_1329222982573_hgE043_jpg%2F1325563347678.jpg&type=f54_54',
#    'source': "I'm on cloud 9 :)",
#    'link': 'https://blog.naver.com/onion03111/223832351708',
#    'snippet': '재료 선정에도 진심인 상일동역 돈까스 맛집 푼푼 왕돈까스. 메뉴도 복잡하게 않게 딱 기본에 집중한 느낌. 우리는 대표메뉴인 푼푼 왕돈까스와 푼푼 스페셜, 그리고 다은이를 위해 싱글 돈까스를 주문했다. 고센푸는 상가는 화장실이 깨끗해서 참 좋다. 이렇게 매장마다 비밀번호로 안내하니 관리가 잘되는 듯 하다. 와이파이 존이니까, 혼밥으로 돈까스 먹으면서...',
#    'thumbnail': 'https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyNTA0MTRfMjg4%2FMDAxNzQ0NTkzNDU3NjAy.nUlpHLfwoYqJd8eq6D6CPMTZIasosqiVp51JtbF4lzkg.BAJKGWrDKAIKAZ5qsLK6Nl1tbgsoX2aK3u7OxK35huEg.JPEG%2FIMG_4783.jpg%23900x676&type=ff192_192'},
#   {'position': 15}],
#  'pagination': {'current': 1,
#   'next': 'https://search.naver.com/search.naver?nso=&page=11&query=%EC%83%81%EC%9D%BC%EB%8F%99%EC%97%AD+%EB%A7%9B%EC%A7%91&sm=tab_pge&start=1&where=web',
#   'other_pages': {'2': 'https://search.naver.com/search.naver?nso=&page=2&query=%EC%83%81%EC%9D%BC%EB%8F%99%EC%97%AD+%EB%A7%9B%EC%A7%91&sm=tab_pge&start=1&where=web',
#    '3': 'https://search.naver.com/search.naver?nso=&page=3&query=%EC%83%81%EC%9D%BC%EB%8F%99%EC%97%AD+%EB%A7%9B%EC%A7%91&sm=tab_pge&start=16&where=web',
#    '4': 'https://search.naver.com/search.naver?nso=&page=4&query=%EC%83%81%EC%9D%BC%EB%8F%99%EC%97%AD+%EB%A7%9B%EC%A7%91&sm=tab_pge&start=31&where=web',
#    '5': 'https://search.naver.com/search.naver?nso=&page=5&query=%EC%83%81%EC%9D%BC%EB%8F%99%EC%97%AD+%EB%A7%9B%EC%A7%91&sm=tab_pge&start=46&where=web',
#    '6': 'https://search.naver.com/search.naver?nso=&page=6&query=%EC%83%81%EC%9D%BC%EB%8F%99%EC%97%AD+%EB%A7%9B%EC%A7%91&sm=tab_pge&start=61&where=web',
#    '7': 'https://search.naver.com/search.naver?nso=&page=7&query=%EC%83%81%EC%9D%BC%EB%8F%99%EC%97%AD+%EB%A7%9B%EC%A7%91&sm=tab_pge&start=76&where=web',
#    '8': 'https://search.naver.com/search.naver?nso=&page=8&query=%EC%83%81%EC%9D%BC%EB%8F%99%EC%97%AD+%EB%A7%9B%EC%A7%91&sm=tab_pge&start=91&where=web',
#    '9': 'https://search.naver.com/search.naver?nso=&page=9&query=%EC%83%81%EC%9D%BC%EB%8F%99%EC%97%AD+%EB%A7%9B%EC%A7%91&sm=tab_pge&start=106&where=web',
#    '10': 'https://search.naver.com/search.naver?nso=&page=10&query=%EC%83%81%EC%9D%BC%EB%8F%99%EC%97%AD+%EB%A7%9B%EC%A7%91&sm=tab_pge&start=121&where=web'}},
#  'serpapi_pagination': {'current': 1,
#   'next_link': 'https://serpapi.com/search.json?device=desktop&engine=naver&page=11&query=%EC%83%81%EC%9D%BC%EB%8F%99%EC%97%AD+%EB%A7%9B%EC%A7%91&start=1&where=web',
#   'next': 'https://serpapi.com/search.json?device=desktop&engine=naver&page=11&query=%EC%83%81%EC%9D%BC%EB%8F%99%EC%97%AD+%EB%A7%9B%EC%A7%91&start=1&where=web',
#   'other_pages': {'2': 'https://serpapi.com/search.json?device=desktop&engine=naver&page=2&query=%EC%83%81%EC%9D%BC%EB%8F%99%EC%97%AD+%EB%A7%9B%EC%A7%91&start=1&where=web',
#    '3': 'https://serpapi.com/search.json?device=desktop&engine=naver&page=3&query=%EC%83%81%EC%9D%BC%EB%8F%99%EC%97%AD+%EB%A7%9B%EC%A7%91&start=16&where=web',
#    '4': 'https://serpapi.com/search.json?device=desktop&engine=naver&page=4&query=%EC%83%81%EC%9D%BC%EB%8F%99%EC%97%AD+%EB%A7%9B%EC%A7%91&start=31&where=web',
#    '5': 'https://serpapi.com/search.json?device=desktop&engine=naver&page=5&query=%EC%83%81%EC%9D%BC%EB%8F%99%EC%97%AD+%EB%A7%9B%EC%A7%91&start=46&where=web',
#    '6': 'https://serpapi.com/search.json?device=desktop&engine=naver&page=6&query=%EC%83%81%EC%9D%BC%EB%8F%99%EC%97%AD+%EB%A7%9B%EC%A7%91&start=61&where=web',
#    '7': 'https://serpapi.com/search.json?device=desktop&engine=naver&page=7&query=%EC%83%81%EC%9D%BC%EB%8F%99%EC%97%AD+%EB%A7%9B%EC%A7%91&start=76&where=web',
#    '8': 'https://serpapi.com/search.json?device=desktop&engine=naver&page=8&query=%EC%83%81%EC%9D%BC%EB%8F%99%EC%97%AD+%EB%A7%9B%EC%A7%91&start=91&where=web',
#    '9': 'https://serpapi.com/search.json?device=desktop&engine=naver&page=9&query=%EC%83%81%EC%9D%BC%EB%8F%99%EC%97%AD+%EB%A7%9B%EC%A7%91&start=106&where=web',
#    '10': 'https://serpapi.com/search.json?device=desktop&engine=naver&page=10&query=%EC%83%81%EC%9D%BC%EB%8F%99%EC%97%AD+%EB%A7%9B%EC%A7%91&start=121&where=web'}}}

# %%
# Gemini 2.5 Flash 모델을 사용하여 네이버 검색 결과에서 식당명을 추출합니다.
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.output_parsers import PydanticOutputParser
from langchain_core.prompts import PromptTemplate
from pydantic import BaseModel, Field
from typing import List
import json


# 식당 정보를 담는 모델 정의
class Restaurant(BaseModel):
    name: str = Field(description="식당명")


# 여러 식당 정보를 담는 모델 정의
class RestaurantList(BaseModel):
    restaurants: List[Restaurant]


# OutputParser 초기화
parser = PydanticOutputParser(pydantic_object=RestaurantList)

# Gemini 2.5 Flash 모델 초기화
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0)

# 프롬프트 템플릿 생성
prompt_template = """
다음 네이버 검색 결과에서 식당명만을 정확히 추출해주세요.
각 검색 결과를 분석하여 식당 이름을 정확히 식별하고 JSON 형식으로 출력해주세요.
블로그나 리뷰 사이트가 아닌 실제 식당명만 추출해주세요.

{format_instructions}

네이버 검색 결과:
{search_data}
"""

prompt = PromptTemplate(
    template=prompt_template,
    input_variables=["search_data"],
    partial_variables={"format_instructions": parser.get_format_instructions()},
)

# 체인 구성: 프롬프트 → 모델 → 파서
chain = prompt | model | parser

# 네이버 검색 결과를 문자열로 변환하여 모델에 전달
search_data_str = json.dumps(results, ensure_ascii=False, indent=2)

# Gemini 모델로 식당명 추출
try:
    result_obj = chain.invoke({"search_data": search_data_str})

    # JSON 출력
    json_str = result_obj.model_dump_json(indent=2)
    print("=== JSON 출력 ===")
    print(json_str)

    print("\n=== 식당명 목록 ===")
    # 보기 좋게 출력
    for i, r in enumerate(result_obj.restaurants, 1):
        print(f"{i}. 식당명: {r.name}")
        print("-" * 30)

except Exception as e:
    print(f"오류 발생: {e}")
    print("네이버 검색 결과에서 식당명을 추출할 수 없습니다.")
# Out:
# === JSON 출력 ===
# {
#   "restaurants": [
#     {
#       "name": "세민수산"
#     },
#     {
#       "name": "양미당"
#     },
#     {
#       "name": "고반식당"
#     },
#     {
#       "name": "돈먹소"
#     },
#     {
#       "name": "참치빠"
#     },
#     {
#       "name": "어반나이프"
#     },
#     {
#       "name": "케이리치버거"
#     },
#     {
#       "name": "푼푼 왕돈까스"
#     }
#   ]
# }
#
# === 식당명 목록 ===
# 1. 식당명: 세민수산
# ------------------------------
# 2. 식당명: 양미당
# ------------------------------
# 3. 식당명: 고반식당
# ------------------------------
# 4. 식당명: 돈먹소
# ------------------------------
# 5. 식당명: 참치빠
# ------------------------------
# 6. 식당명: 어반나이프
# ------------------------------
# 7. 식당명: 케이리치버거
# ------------------------------
# 8. 식당명: 푼푼 왕돈까스
# ------------------------------
